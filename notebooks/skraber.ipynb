# %%
import pandas as pd
import urllib
dir(urllib)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'error',
#  'parse',
#  'request',
#  'response']

# %%
link = 'http://www.atpworldtour.com/en/tournaments/australian-open/580/2016/match-stats/MC10/R975/live/MS003/match-stats'

data = urllib.request.urlopen(link)
#f = urllib.urlopen(link)
#myfile = f.read()

#print(myfile)

# %%
d = data.read()

# %%
from html import parser
d.decode('utf-8')
# Out:
# '\r\n<!DOCTYPE html>\r\n<!-- START : /modules/global/head -->\r\n<!--[if lt IE 7]>\r\n    <html class="no-js lt-ie10 lt-ie9 lt-ie8 lt-ie7 ">\r\n<![endif]-->\r\n<!--[if IE 7]>\r\n    <html class="no-js lt-ie10 lt-ie9 lt-ie8 ">\r\n<![endif]-->\r\n<!--[if IE 8]>\r\n    <html class="no-js lt-ie10 lt-ie9 ">\r\n<![endif]-->\r\n<!--[if IE 9]>\r\n    <html class="no-js lt-ie10 ">\r\n<![endif]-->\r\n<!--[if gt IE 9]><!-->\r\n<html class="no-js ">\r\n<!--<![endif]-->\r\n\t<head>\r\n\t\t<!-- disable auto format for telephone numbers -->\r\n\t\t<meta name="format-detection" content="telephone=no">\r\n\t\t\r\n\r\n<title>\r\n\tAndy Murray VS Milos Raonic |  Match Stats | ATP World Tour | Tennis\r\n</title>\r\n\r\n<meta name="viewport" content="initial-scale=1.0, width=768, user-scalable=yes, minimum-scale=1.0, maximum-scale=1.25">\r\n\r\n<meta charset="UTF-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n\r\n<meta name="keywords" content="">\r\n<meta name="description" content="">\r\n\r\n<meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE">\r\n<meta name="thumbnail" content="" />\r\n\r\n<meta property="pageTransitionTitle" content="Andy Murray VS Milos Raonic" />\r\n<meta property="fb:app_id" content="132901818553" />\r\n<meta property=\'og:locale\' content=\'en\' />\r\n<meta property=\'og:type\' content=\'article\' />\r\n<meta property=\'og:title\' content=\'Andy Murray VS Milos Raonic |  Match Stats | ATP World Tour | Tennis\' />\r\n<meta property=\'og:description\' content=\'\' />\r\n<meta property=\'og:image\' content=\'\' />\r\n<meta property=\'og:url\' content=\'www.atpworldtour.com/en/tournaments/australian-open/580/overview\' />\r\n<meta property=\'og:site_name\' content=\'ATP World Tour\' />\r\n\r\n<meta name="twitter:card" content="summary" />\r\n<meta name="twitter:title" content="Andy Murray VS Milos Raonic |  Match Stats | ATP World Tour | Tennis" />\r\n<meta name="twitter:creator" content="@atpworldtour" />\r\n<meta name="twitter:description" content="" />\r\n\t\t\r\n\t<script>\r\n\t\t(function (i, s, o, g, r, a, m) {\r\n\t\t\ti[\'GoogleAnalyticsObject\'] = r; i[r] = i[r] || function () {\r\n\t\t\t\t(i[r].q = i[r].q || []).push(arguments)\r\n\t\t\t}, i[r].l = 1 * new Date(); a = s.createElement(o),\r\n\t\t\tm = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)\r\n\t\t})(window, document, \'script\', \'//www.google-analytics.com/analytics.js\', \'ga\');\r\n\r\n\t\tga(\'create\', \'UA-4616629-30\', \'auto\');\r\n\t\tga(\'send\', \'pageview\');\r\n\r\n\t</script>\r\n\t\t<script src="/assets/js/vendor/vixlet-bootstrap.js?bust=635779520840000000"></script>\r\n\r\n\t\t<script>\r\n\t\tvar cacheBuster = 636171678196311982\r\n\t</script>\r\n\r\n\t\t<link rel="stylesheet" href="/assets/css/ATPWorldTour/desktop.css?bust=636171678210323769" />\r\n\r\n\t<script src="/assets/js/vendor/require.js"></script>\r\n\t\t<script src="/assets/js/desktop.js?bust=636171678196311982"></script>\r\n\r\n\r\n\t\t<!--[if lt IE 10]>\r\n\t\t<script src="/assets/js/vendor/matchMedia.js"></script>\r\n\t\t<script src="/assets/js/vendor/matchMedia.addListener.js"></script>\r\n\t\t<![endif]-->\r\n\t\t<link rel="icon" href="/assets/images/global/favicon.ico">\r\n\t\t<script>\r\n\t\t\tvar _comscore = _comscore || [];\r\n\t\t\t_comscore.push(\r\n\t\t\t{ c1: "2", c2: "17223859" }\r\n\t\t\t);\r\n\t\t\t(function ()\r\n\t\t\t{ var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); }\r\n\t\t\t)();\r\n\t\t</script>\r\n\t\t<noscript>\r\n\t\t\t<img src="http://b.scorecardresearch.com/p?c1=2&c2=17223859&cv=2.0&cj=1" />\r\n\t\t</noscript>\r\n\t\t<!-- RUM\'s Header 1.3.3.0 -->\r\n\t</head>\r\n<!-- END : /modules/global/head -->\r\n\r\n\r\n<body class="is-desktop" data-signalr-url="http://push.atpworldtour ...

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Encountered a start tag:", tag)

    def handle_endtag(self, tag):
        print("Encountered an end tag :", tag)

    def handle_data(self, data):
        print("Encountered some data  :", data)

parser = MyHTMLParser()
#parser.feed('<html><head><title>Test</title></head>'
#            '<body><h1>Parse me!</h1></body></html>')
parser.feed(d.decode('utf-8'))
# Out:
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered a start tag: html
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered a start tag: head
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered some data  :
#
#
#
# Encountered a start tag: title
# Encountered some data  :
# 	Andy Murray VS Milos Raonic |  Match Stats | ATP World Tour | Tennis
#
# Encountered an end tag : title
# Encountered some data  :
#
#
# Encountered a start tag: meta
# Encountered some data  :
#
#
# Encountered a start tag: meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered some data  :
#
#
# Encountered a start tag: meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered some data  :
#
#
# Encountered a start tag: meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered some data  :
# 		(function (i, s, o, g, r, a, m) {
# 			i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# 				(i[r].q = i[r].q || []).push(arguments)
# 			}, i[r].l = 1 * new Date(); a = s.createElement(o),
# 			m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# 		})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# 		ga('create', 'UA-4616629-30', 'auto');
# 		ga('send', 'pageview');
#
#
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered an end tag : script
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered some data  :
# 		var cacheBuster = 636171678196311982
#
# Encountered an end tag : script
# Encountered some data  :
#
#
# Encountered a start tag: link
# Encountered an end tag : link
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered an end tag : script
# Encountered some data  :
#
#
#
# Encountered some data  :
#
# Encountered a start tag: link
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
# 			var _comscore = _comscore || [];
# 			_comscore.push(
# 			{ c1: "2", c2: "17223859" }
# 			);
# 			(function ()
# 			{ var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); }
# 			)();
#
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: noscript
# Encountered some data  :
#
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
# Encountered an end tag : noscript
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered an end tag : head
# Encountered some data  :
#
# Encountered some data  :
#
#
#
# Encountered a start tag: body
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
#
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: ul
# Encountered some data  :
#
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
# 						ProTennisLive App
#
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
# 						ATP Challenger Tour
#
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
# 						ATP Champions Tour
#
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
# Encountered a start tag: span
# Encountered an end tag : span
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: ul
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
# 									English
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
# 									Spanish
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
# 									Chinese
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
# 	require(["modules/global/languageSwitcher"], function (LanguageSwitcher) {
# 		return new LanguageSwitcher({
# 			elementId: "#languageDropdown"
# 		});
# 	});
#
# Encountered an end tag : script
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
# 				Menu
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: h1
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
# Encountered a start tag: span
# Encountered some data  :
# 		ATP World Tour
#
# Encountered an end tag : span
# Encountered some data  :
#
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : h1
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: nav
# Encountered some data  :
#
# Encountered a start tag: ul
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Scores
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Scores, Draws & Schedules
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Results Archive
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : ProTennisLive App
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Stats
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Stats Home
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Stats Leaderboards
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Year-end No. 1s
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Individual Match Stats
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Rankings
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Rankings Home
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Singles
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Doubles
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Doubles Race
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Former No. 1s
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Rankings FAQ
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Players
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Players Home
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Performance Zone
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Win Loss Index
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : ATP Trivia Challenge
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : #NextGen
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Coaches
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Tournaments
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Calendar
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Barclays ATP World Tour Finals
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Next Gen ATP Finals
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : ATP World Tour Masters 1000
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : ATP Challenger Tour
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : TV Schedule
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Tickets
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : News
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Landing
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Latest
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : On Court
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Off Court
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Story of the Season
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : ATP Heritage
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : ATP Awards
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : #NextGen
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : On The Road
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Video
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Landing
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Latest
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Hot Shots
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Highlights
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Interviews
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Player Profiles
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Uncovered
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Watch Live
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Photos
# Encountered an end tag : a
# Encountered an end tag : li
# Encountered some data  :
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : MyATP
# Encountered an end tag : a
# Encountered an end tag : li
# Encountered a start tag: li
# Encountered a start tag: a
# Encountered some data  : More
# Encountered an end tag : a
# Encountered a start tag: ul
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Video
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : Photos
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered a start tag: li
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  : MyATP
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered an end tag : li
# Encountered some data  :
#
# Encountered an end tag : ul
# Encountered some data  :
#
# Encountered an end tag : nav
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
#
#
# Encountered a start tag: span
# Encountered an end tag : span
# Encountered some data  :
#
#
# Encountered a start tag: a
# Encountered some data  : #Shop#
# Encountered an end tag : a
# Encountered some data  :
#
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
# 						 Search
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered some data  :
#
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered some data  :
# 	require(["modules/global/fixedHeader"], function (FixedHeader) {
# 		return new FixedHeader({
# 			moreText: "More"
# 		});
# 	});
#
# 	require(["modules/global/headerNav"], function (HeaderNav) {
# 		return HeaderNav.get();
# 	});
#
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
#
# 	require(["jquery"], function ($) {
# 		var $shopLink = $(".shop-link");
# 		var req = new XMLHttpRequest();
# 		req.open("GET", document.location, false);
# 		req.send(null);
# 		var xRegion = req.getResponseHeader("x-region");
# 		var href = "";
# 		var regionLink = {
# 			us: "http://www.tennis-warehouse.com/?from=atp",
# 			eu: "http://www.tenniswarehouse-europe.com/?from=atp",
# 			au: "http://www.tennis-warehouse.com/?from=atp",
# 			na: "http://www.tennis-warehouse.com/?from=atp"
# 		}
#
# 		var chkShop = function (header) {
# 			if (header === null) {
# 				return $shopLink.attr("href", regionLink.us);
# 			}
# 			var regKey = header.toLowerCase();
#
# 			href = regionLink[regKey];
# 			return $shopLink.attr("href", href);
# 		}
# 		chkShop(xRegion);
# 	});
#
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
# 	<div id="navigation" class="navigation">
# 		<div id="mainNav" class="main-nav">
# 			<div class="nav-section">
# 				<span class="nav-section-title">Menu</span>
# 				<ul class="nav-list">
# 						<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Scores&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Scores&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Scores, Draws &amp; Schedules&quot;,
#       &quot;Link&quot;: &quot;/en/scores/current/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Scores, Draws &amp; Schedules&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Results Archive&quot;,
#       &quot;Link&quot;: &quot;/en/scores/results-archive&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Results Archive&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ProTennisLive App&quot;,
#       &quot;Link&quot;: &quot;javascript:openLSHDWindow(2016,&#39;99&#39;,&#39;&#39;,&#39;1&#39;,&#39;en&#39;,&#39;http://www.atpworldtour.com&#39;)&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ProTennisLive App&quot;
#     }
#   ]
# }">
# <a href="/en/scores" data-ga-label="Scores" data-ga-category="Main Navigation" data-ga-action="Click" data-use-ga="true" class="nav-push">Scores</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Stats&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Stats&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Stats Home&quot;,
#       &quot;Link&quot;: &quot;/en/stats&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Stats Home&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Stats Leaderboards&quot;,
#       &quot;Link&quot;: &quot;javascript:window.location.assign(&#39;/en/stats/leaderboard?page=serve&#39;)&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Stats Leaderboards&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Year-end No. 1s&quot;,
#       &quot;Link&quot;: &quot;/en/stats/year-end-no1s&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Year-end No. 1s&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Individual Match Stats&quot;,
#       &quot;Link&quot;: &quot;/en/stats/service-games-won&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Individual Match Stats&quot;
#     }
#   ]
# }">
# <a href="/en/stats" data-ga-label="Stats" data-ga-category="Main Navigation" data-ga-action="Click" data-use-ga="true" class="nav-push">Stats</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Rankings&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Rankings&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Rankings Home&quot;,
#       &quot;Link&quot;: &quot;/en/rankings&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Rankings Home&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Singles&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/singles&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Singles&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Doubles&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/doubles&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Doubles&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Doubles Race&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/doubles-race-to-london&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Doubles Race&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Former No. 1s&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/former-no-1s&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Former No. 1s&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Rankings FAQ&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/rankings-faq&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Rankings FAQ&quot;
#     }
#   ]
# }">
# <a href="/en/rankings" data-ga-label="Rankings" data-ga-category="Main Navigation" data-ga-action="Click" data-use-ga="true" class="nav-push">Rankings</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Players&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Players&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Players Home&quot;,
#       &quot;Link&quot;: &quot;/en/players&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Players Home&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Performance Zone&quot;,
#       &quot;Link&quot;: &quot;/en/performance-zone&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Performance Zone&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Win Loss Index&quot;,
#       &quot;Link&quot;: &quot;/en/performance-zone/win-loss-index&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Win Loss Index&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Trivia Challenge&quot;,
#       &quot;Link&quot;: &quot;/en/performance-zone/atp-trivia-challenge&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Trivia Challenge&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;#NextGen&quot;,
#       &quot;Link&quot;: &quot;/en/news/nextgen&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;#NextGen&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Coaches&quot;,
#       &quot;Link&quot;: &quot;/en/players/coaches&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Coaches&quot;
#     }
#   ]
# }">
# <a href="/en/players" data-ga-label="Players" data-ga-category="Main Navigation" data-ga-action="Click" data-use-ga="true" class="nav-push">Players</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Tournaments&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Tournaments&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Calendar&quot;,
#       &quot;Link&quot;: &quot;/en/tournaments&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Calendar&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Barclays ATP World Tour Finals&quot;,
#       &quot;Link&quot;: &quot;http://www.barclaysatpworldtourfinals.com/en&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Barclays ATP World Tour Finals&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Next Gen ATP Finals&quot;,
#       &quot;Link&quot;: &quot;/en/next-gen-atp-finals&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Next Gen ATP Finals&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP World Tour Masters 1000&quot;,
#       &quot;Link&quot;: &quot;/en/masters-1000&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP World Tour Masters 1000&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Challenger Tour&quot;,
#       &quot;Link&quot;: &quot;/en/atp-challenger-tour&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Challenger Tour&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;TV Schedule&quot;,
#       &quot;Link&quot;: &quot;/en/tournaments/tv-schedule&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;TV Schedule&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Tickets&quot;,
#       &quot;Link&quot;: &quot;/en/tournaments/tickets&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Tickets&quot;
#     }
#   ]
# }">
# <a href="/en/tournaments" data-ga-label="Tournaments" data-ga-category="Main Navigation" data-ga-action="Click" data-use-ga="true" class="nav-push">Tournaments</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;News&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;News&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Landing&quot;,
#       &quot;Link&quot;: &quot;/en/news&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Landing&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Latest&quot;,
#       &quot;Link&quot;: &quot;/en/news/news-filter-results/all/all/all/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Latest&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;On Court&quot;,
#       &quot;Link&quot;: &quot;/en/news/news-filter-results/all/on-court/all/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;On Court&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Off Court&quot;,
#       &quot;Link&quot;: &quot;/en/news/news-filter-results/all/off-court/all/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Off Court&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Story of the Season&quot;,
#       &quot;Link&quot;: &quot;/en/news/story-of-the-season&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Story of the Season&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Heritage&quot;,
#       &quot;Link&quot;: &quot;/en/news/atp-heritage&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Heritage&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Awards&quot;,
#       &quot;Link&quot;: &quot;/en/news/atp-awards-presented-by-moet-chandon&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Awards&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;#NextGen&quot;,
#       &quot;Link&quot;: &quot;/en/news/nextgen&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;#NextGen&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;On The Road&quot;,
#       &quot;Link&quot;: &quot;/en/news/on-the-road&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;On The Road&quot;
#     }
#   ]
# }">
# <a href="/en/news" data-ga-label="News" data-ga-category="Main Navigation" data-ga-action="Click" data-use-ga="true" class="nav-push">News</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Video&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Video&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Landing&quot;,
#       &quot;Link&quot;: &quot;/en/video&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Landing&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Latest&quot;,
#       &quot;Link&quot;: &quot;/en/video/video-filter-results/all/all/all/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Latest&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Hot Shots&quot;,
#       &quot;Link&quot;: &quot;/en/video/video-filter-results/all/video/hot-shot/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Hot Shots&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Highlights&quot;,
#       &quot;Link&quot;: &quot;/en/video/video-filter-results/all/video/highlights/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Highlights&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Interviews&quot;,
#       &quot;Link&quot;: &quot;/en/video/video-filter-results/all/video/interviews/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Interviews&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Player Profiles&quot;,
#       &quot;Link&quot;: &quot;/en/video/video-filter-results/all/video/atp-player-profiles/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Player Profiles&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Uncovered&quot;,
#       &quot;Link&quot;: &quot;/en/uncovered&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Uncovered&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Watch Live&quot;,
#       &quot;Link&quot;: &quot;/en/video/watch-live&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Watch Live&quot;
#     }
#   ]
# }">
# <a href="/en/video" data-ga-label="Video" data-ga-category="Main Navigation" data-ga-action="Click" data-use-ga="true" class="nav-push">Video</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Photos&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Photos&quot;,
#   &quot;MenuItems&quot;: []
# }">
# <a href="/en/photos" data-ga-label="Photos" data-ga-category="Main Navigation" data-ga-action="Click">Photos</a>	</li>
# 	<li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;MyATP&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;MyATP&quot;,
#   &quot;MenuItems&quot;: []
# }">
# <a href="/en/myatp" data-ga-label="MyATP" data-ga-category="Main Navigation" data-ga-action="Click">MyATP</a>	</li>
#
# 				</ul>
# 			</div>
# 			<div class="nav-section">
# 				<span class="nav-section-title">Other Tours</span>
#
#
# 					<div class="nav-section change-language">
# 						<span class="nav-section-title">Change Language</span>
# 						<div class="language-flags">
# 								<a href="/en/tournaments/,-w-,/,-w-,/,-w-,/match-stats/,-w-,/,-w-,/match-stats" class=current><img src="/-/media/images/flags/gbr.svg?h=32&amp;la=en&amp;w=44&amp;hash=18D7DB75993A84C9DDB25CF0DD6E045997041A98" alt="USA" width="44" height="32" /></a>
# 								<a href="/en/tournaments/,-w-,/,-w-,/,-w-,/match-stats/,-w-,/,-w-,/match-stats" ><img src="/-/media/images/flags/esp.svg?h=32&amp;la=en&amp;w=44&amp;hash=3834AC39CA9018029C4541A6EDA8FCAC2F53432D" alt="zh" width="44" height="32" /></a>
# 								<a href="/en/tournaments/,-w-,/,-w-,/,-w-,/match-stats/,-w-,/,-w-,/match-stats" ><img src="/-/media/images/flags/chn.svg?h=32&amp;la=en&amp;w=44&amp;hash=3947791DD1FA1513BD0F57540DF54D7EC11F9947" alt="zh" width="44" height="32" /></a>
# 						</div>
# 					</div>
# 				<button id="closeNav" class="close-nav">
# 					<span>
# 						Close
# 					</span>
# 				</button>
# 			</div>
# 		</div>
# 		<div id="subNav" class="sub-nav"></div>
# 	</div>
#
# Encountered an end tag : script
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered some data  :
# 	<span class="sub-nav-title"><%- rc.Title %></span>
# 	<a href="<%- rc.SponsorLink %>" target="_blank" class="sponsor-logo" data-ga-label="<%- rc.AnalyticsLabel %>" dada-ga-category="<%- rc.AnalyticsCategory %>" data-ga-action="<%- rc.AnalyticsAction %>"><img alt="" src="<%- rc.SponsorLogo %>" /></a>
# 	<div class="nav-section">
# 		<ul class="nav-list">
# 			<% _.each( rc.MenuItems, function( menuItem ) { %>
# 			<li><a href="<%- menuItem.Link %>" data-ga-label="<%- menuItem.AnalyticsLabel %>" data-ga-category="<%- menuItem.AnalyticsCategory %>" data-ga-action="<%- menuItem.AnalyticsAction %>"><%- menuItem.Title %></a></li>
# 			<% }); %>
# 		</ul>
# 	</div>
# 	<div class="iab-wrapper"><a href="<%- rc.AdvertLink %>"><img alt="" src="<%- rc.AdvertImage %><%- rc.AdvertSize %>" /></a></div>
#
# Encountered an end tag : script
# Encountered some data  :
#
#
#
#
#
#
#
#
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: a
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: h2
# Encountered some data  :
#
# Encountered a start tag: img
# Encountered an end tag : img
# Encountered some data  :
#
# Encountered an end tag : h2
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: h3
# Encountered some data  :
# 		Australian Open
#
# Encountered an end tag : h3
# Encountered some data  :
#
#
# Encountered some data  :
#
# Encountered a start tag: div
# Encountered some data  :
#
# Encountered a start tag: div
# ...
# 		</td>
# 		<td class="match-stats-label">
# 			1st Serve Return Points Won
# 		</td>
# 		<td class="match-stats-bar-right">
# 			<div data-percent="<%=opponentStats.FirstServeReturnPointsPercentage%>%" class="match-stats-bar-length" id="580__TeamTwo_<%=setNum%>_FirstServeReturnPoints_Perc"></div>
# 		</td>
# 		<td class="match-stats-number-right">
# 					<span id="580__TeamTwo_<%=setNum%>_FirstServeReturnPointsPercentage">
# 			<%=opponentStats.FirstServeReturnPointsPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamTwo_<%=setNum%>_FirstServeReturnPointsDividend"><%=opponentStats.FirstServeReturnPointsDividend%></span>/<span id="580__TeamTwo_<%=setNum%>_FirstServeReturnPointsDivisor"><%=opponentStats.FirstServeReturnPointsDivisor%></span>)
# 		</span>
#
# 		</td>
# 	</tr>
#
# 				<tr class="match-stats-row">
# 		<td class="match-stats-number-left">
# 					<span id="580__TeamOne_<%=setNum%>_SecondServePointsPercentage">
# 			<%=playerStats.SecondServePointsPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamOne_<%=setNum%>_SecondServePointsDividend"><%=playerStats.SecondServePointsDividend%></span>/<span id="580__TeamOne_<%=setNum%>_SecondServePointsDivisor"><%=playerStats.SecondServePointsDivisor%></span>)
# 		</span>
#
# 		</td>
# 		<td class="match-stats-bar-left">
# 			<div data-percent="<%=playerStats.SecondServePointsPercentage%>%" class="match-stats-bar-length" id="580__TeamOne_<%=setNum%>_SecondServePoints_Perc"></div>
# 		</td>
# 		<td class="match-stats-label">
# 			2nd Serve Return Points Won
# 		</td>
# 		<td class="match-stats-bar-right">
# 			<div data-percent="<%=opponentStats.SecondServePointsPercentage%>%" class="match-stats-bar-length" id="580__TeamTwo_<%=setNum%>_SecondServePoints_Perc"></div>
# 		</td>
# 		<td class="match-stats-number-right">
# 					<span id="580__TeamTwo_<%=setNum%>_SecondServePointsPercentage">
# 			<%=opponentStats.SecondServePointsPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamTwo_<%=setNum%>_SecondServePointsDividend"><%=opponentStats.SecondServePointsDividend%></span>/<span id="580__TeamTwo_<%=setNum%>_SecondServePointsDivisor"><%=opponentStats.SecondServePointsDivisor%></span>)
# 		</span>
#
# 		</td>
# 	</tr>
#
# 				<tr class="match-stats-row">
# 		<td class="match-stats-number-left">
# 					<span id="580__TeamOne_<%=setNum%>_BreakPointsConvertedPercentage">
# 			<%=playerStats.BreakPointsConvertedPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamOne_<%=setNum%>_BreakPointsConvertedDividend"><%=playerStats.BreakPointsConvertedDividend%></span>/<span id="580__TeamOne_<%=setNum%>_BreakPointsConvertedDivisor"><%=playerStats.BreakPointsConvertedDivisor%></span>)
# 		</span>
#
# 		</td>
# 		<td class="match-stats-bar-left">
# 			<div data-percent="<%=playerStats.BreakPointsConvertedPercentage%>%" class="match-stats-bar-length" id="580__TeamOne_<%=setNum%>_BreakPointsConverted_Perc"></div>
# 		</td>
# 		<td class="match-stats-label">
# 			Break Points Converted
# 		</td>
# 		<td class="match-stats-bar-right">
# 			<div data-percent="<%=opponentStats.BreakPointsConvertedPercentage%>%" class="match-stats-bar-length" id="580__TeamTwo_<%=setNum%>_BreakPointsConverted_Perc"></div>
# 		</td>
# 		<td class="match-stats-number-right">
# 					<span id="580__TeamTwo_<%=setNum%>_BreakPointsConvertedPercentage">
# 			<%=opponentStats.BreakPointsConvertedPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamTwo_<%=setNum%>_BreakPointsConvertedDividend"><%=opponentStats.BreakPointsConvertedDividend%></span>/<span id="580__TeamTwo_<%=setNum%>_BreakPointsConvertedDivisor"><%=opponentStats.BreakPointsConvertedDivisor%></span>)
# 		</span>
#
# 		</td>
# 	</tr>
#
# 				<tr class="match-stats-row">
# 		<td class="match-stats-number-left">
# 					<span id="580__TeamOne_<%=setNum%>_ReturnGamesPlayed">
# 			<%=playerStats.ReturnGamesPlayed%>
# 		</span>
#
# 		</td>
# 		<td class="match-stats-bar-left">
# 			<div data-percent="<%=playerStats.ReturnGamesPlayedPercentage%>%" class="match-stats-bar-length" id="580__TeamOne_<%=setNum%>_ReturnGamesPlayed_Perc"></div>
# 		</td>
# 		<td class="match-stats-label">
# 			Return Games Played
# 		</td>
# 		<td class="match-stats-bar-right">
# 			<div data-percent="<%=opponentStats.ReturnGamesPlayedPercentage%>%" class="match-stats-bar-length" id="580__TeamTwo_<%=setNum%>_ReturnGamesPlayed_Perc"></div>
# 		</td>
# 		<td class="match-stats-number-right">
# 					<span id="580__TeamTwo_<%=setNum%>_ReturnGamesPlayed">
# 			<%=opponentStats.ReturnGamesPlayed%>
# 		</span>
#
# 		</td>
# 	</tr>
#
#
# 				<tr>
# 		<th colspan="5">
# 			#PhraseItemNotFound#
# 		</th>
# 	</tr>
#
# 				<tr class="match-stats-row">
# 		<td class="match-stats-number-left">
# 					<span id="580__TeamOne_<%=setNum%>_TotalServicePointsWonPercentage">
# 			<%=playerStats.TotalServicePointsWonPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamOne_<%=setNum%>_TotalServicePointsWonDividend"><%=playerStats.TotalServicePointsWonDividend%></span>/<span id="580__TeamOne_<%=setNum%>_TotalServicePointsWonDivisor"><%=playerStats.TotalServicePointsWonDivisor%></span>)
# 		</span>
#
# 		</td>
# 		<td class="match-stats-bar-left">
# 			<div data-percent="<%=playerStats.TotalServicePointsWonPercentage%>%" class="match-stats-bar-length" id="580__TeamOne_<%=setNum%>_TotalServicePointsWon_Perc"></div>
# 		</td>
# 		<td class="match-stats-label">
# 			Return Points Won
# 		</td>
# 		<td class="match-stats-bar-right">
# 			<div data-percent="<%=opponentStats.TotalServicePointsWonPercentage%>%" class="match-stats-bar-length" id="580__TeamTwo_<%=setNum%>_TotalServicePointsWon_Perc"></div>
# 		</td>
# 		<td class="match-stats-number-right">
# 					<span id="580__TeamTwo_<%=setNum%>_TotalServicePointsWonPercentage">
# 			<%=opponentStats.TotalServicePointsWonPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamTwo_<%=setNum%>_TotalServicePointsWonDividend"><%=opponentStats.TotalServicePointsWonDividend%></span>/<span id="580__TeamTwo_<%=setNum%>_TotalServicePointsWonDivisor"><%=opponentStats.TotalServicePointsWonDivisor%></span>)
# 		</span>
#
# 		</td>
# 	</tr>
#
# 				<tr class="match-stats-row">
# 		<td class="match-stats-number-left">
# 					<span id="580__TeamOne_<%=setNum%>_TotalReturnPointsWonPercentage">
# 			<%=playerStats.TotalReturnPointsWonPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamOne_<%=setNum%>_TotalReturnPointsWonDividend"><%=playerStats.TotalReturnPointsWonDividend%></span>/<span id="580__TeamOne_<%=setNum%>_TotalReturnPointsWonDivisor"><%=playerStats.TotalReturnPointsWonDivisor%></span>)
# 		</span>
#
# 		</td>
# 		<td class="match-stats-bar-left">
# 			<div data-percent="<%=playerStats.TotalReturnPointsWonPercentage%>%" class="match-stats-bar-length" id="580__TeamOne_<%=setNum%>_TotalReturnPointsWon_Perc"></div>
# 		</td>
# 		<td class="match-stats-label">
# 			#TotalReturnPointsWon#
# 		</td>
# 		<td class="match-stats-bar-right">
# 			<div data-percent="<%=opponentStats.TotalReturnPointsWonPercentage%>%" class="match-stats-bar-length" id="580__TeamTwo_<%=setNum%>_TotalReturnPointsWon_Perc"></div>
# 		</td>
# 		<td class="match-stats-number-right">
# 					<span id="580__TeamTwo_<%=setNum%>_TotalReturnPointsWonPercentage">
# 			<%=opponentStats.TotalReturnPointsWonPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamTwo_<%=setNum%>_TotalReturnPointsWonDividend"><%=opponentStats.TotalReturnPointsWonDividend%></span>/<span id="580__TeamTwo_<%=setNum%>_TotalReturnPointsWonDivisor"><%=opponentStats.TotalReturnPointsWonDivisor%></span>)
# 		</span>
#
# 		</td>
# 	</tr>
#
# 				<tr class="match-stats-row">
# 		<td class="match-stats-number-left">
# 					<span id="580__TeamOne_<%=setNum%>_TotalPointsWonPercentage">
# 			<%=playerStats.TotalPointsWonPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamOne_<%=setNum%>_TotalPointsWonDividend"><%=playerStats.TotalPointsWonDividend%></span>/<span id="580__TeamOne_<%=setNum%>_TotalPointsWonDivisor"><%=playerStats.TotalPointsWonDivisor%></span>)
# 		</span>
#
# 		</td>
# 		<td class="match-stats-bar-left">
# 			<div data-percent="<%=playerStats.TotalPointsWonPercentage%>%" class="match-stats-bar-length" id="580__TeamOne_<%=setNum%>_TotalPointsWon_Perc"></div>
# 		</td>
# 		<td class="match-stats-label">
# 			Total Points Won
# 		</td>
# 		<td class="match-stats-bar-right">
# 			<div data-percent="<%=opponentStats.TotalPointsWonPercentage%>%" class="match-stats-bar-length" id="580__TeamTwo_<%=setNum%>_TotalPointsWon_Perc"></div>
# 		</td>
# 		<td class="match-stats-number-right">
# 					<span id="580__TeamTwo_<%=setNum%>_TotalPointsWonPercentage">
# 			<%=opponentStats.TotalPointsWonPercentage%>%
# 		</span>
# 		<span class="stat-breakdown">
# 			(<span id="580__TeamTwo_<%=setNum%>_TotalPointsWonDividend"><%=opponentStats.TotalPointsWonDividend%></span>/<span id="580__TeamTwo_<%=setNum%>_TotalPointsWonDivisor"><%=opponentStats.TotalPointsWonDivisor%></span>)
# 		</span>
#
# 		</td>
# 	</tr>
#
# 		</table>
#
# Encountered an end tag : script
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered some data  :
# 		require(["modules/modal/modalScoresMatchStats"], function (ModalScoresMatchStats) {
# 			return new ModalScoresMatchStats({
# 				matchStatsContainer: "#matchStatsContainer",
# 				matchStatsTemplate: "#matchStatsTemplate",
# 				currentMatchStatsToggle: "currentMatchStatsButton",
# 				liveMatchUrl: "/-/ajax/scores/GetLiveMatchInfo?tournamentId=580",
# 				setPhrase: "Set",
# 				matchPhrase: "Match",
# 				liveMatchDetails: {
# 					isMatchLive: 'False',
# 					eventId: '580',
# 					matchId: ''
# 				}
# 			},
# 			{
# 				moduleContainer: "#playerStatsContainer",
# 				tabContainer: "#matchStatsToggleContainer",
# 				inlineTemplateTab: "[data-inline-template-tab]"
# 			});
# 		});
#
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
# 		<div class="button-border-row-holder tabs-content-mode hide">
#
# 			<div class="button-row" id="matchStatsButtonContainer"></div>
# 		</div>
# 		<div id="matchStatsContainer">
# 		</div>
#
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
# 	<table class="h2h-table h2h-table-ytd">
# 		<thead>
# 			<tr>
# 				<th colspan="3">
# 					Service Record Year-to-Date
# 				</th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 				<tr>
# 		<td>
# 			551
# 		</td>
# 		<td>
# 			Aces
# 		</td>
# 		<td>
# 			874
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			218
# 		</td>
# 		<td>
# 			Double Faults
# 		</td>
# 		<td>
# 			228
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			60%
# 		</td>
# 		<td>
# 			#PhraseItemNotFound#
# 		</td>
# 		<td>
# 			64%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			76%
# 		</td>
# 		<td>
# 			1st Serve Points Won
# 		</td>
# 		<td>
# 			80%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			54%
# 		</td>
# 		<td>
# 			2nd Serve Points Won
# 		</td>
# 		<td>
# 			55%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			446
# 		</td>
# 		<td>
# 			Break Points Faced
# 		</td>
# 		<td>
# 			281
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			66%
# 		</td>
# 		<td>
# 			Break Points Saved
# 		</td>
# 		<td>
# 			69%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			1009
# 		</td>
# 		<td>
# 			Service Games Played
# 		</td>
# 		<td>
# 			911
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			85%
# 		</td>
# 		<td>
# 			Service Games Won
# 		</td>
# 		<td>
# 			91%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			67%
# 		</td>
# 		<td>
# 			Total Service Points Won
# 		</td>
# 		<td>
# 			71%
# 		</td>
# 	</tr>
#
# 		</tbody>
# 	</table>
# 	<table class="h2h-table h2h-table-ytd">
# 		<thead>
# 			<tr>
# 				<th colspan="3">
# 					Return Record Year-to-Date
# 				</th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 				<tr>
# 		<td>
# 			34%
# 		</td>
# 		<td>
# 			1st Serve Return Points Won
# 		</td>
# 		<td>
# 			28%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			56%
# 		</td>
# 		<td>
# 			2nd Serve Return Points Won
# 		</td>
# 		<td>
# 			49%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			793
# 		</td>
# 		<td>
# 			Break Points Opportunities
# 		</td>
# 		<td>
# 			462
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			45%
# 		</td>
# 		<td>
# 			Break Points Converted
# 		</td>
# 		<td>
# 			35%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			977
# 		</td>
# 		<td>
# 			Return Games Played
# 		</td>
# 		<td>
# 			893
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			37%
# 		</td>
# 		<td>
# 			Return Games Won
# 		</td>
# 		<td>
# 			18%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			42%
# 		</td>
# 		<td>
# 			Return Points Won
# 		</td>
# 		<td>
# 			36%
# 		</td>
# 	</tr>
# 	<tr>
# 		<td>
# 			55%
# 		</td>
# 		<td>
# 			Total Points Won
# 		</td>
# 		<td>
# 			53%
# 		</td>
# 	</tr>
#
# 		</tbody>
# 	</table>
#
# Encountered an end tag : script
# Encountered some data  :
#
#
#
#
#
#
# Encountered some data  :
#
#
#
#
#
#
#
#
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
# 		require(["modules/modal/head2HeadModalContainer"], function (Head2HeadModalContainer) {
# 			return new Head2HeadModalContainer({
# 				element : "#modal"
# 			});
# 		});
#
# Encountered an end tag : script
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
# Encountered some data  :
#
#
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered some data  :
#
# Encountered some data  :
#
# Encountered some data  :
#
#
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered some data  :
# 		function openLSHDWindow(year, wkno, eventid, tour, lang, ref_file, width, height, hasScrollBars) {
# 			// ADD NAME FIELD and make sure it get's focus!!!
# 			var theWidth = width;
# 			var theHeight = height;
# 			var scrollBars = "scrollbars";
# 			if (hasScrollBars == false) scrollBars = "scrollbars=0";
# 			if ((theWidth == "") || (theWidth == null)) theWidth = 1042;
# 			if ((theHeight == "") || (theHeight == null)) theHeight = 631;
# 			var theLeft = (screen.availWidth - theWidth) / 2;
# 			var theTop = (screen.availHeight - theHeight) / 2;
# 			var strCheckRef = escape(ref_file);
#
# 			var lsURL = "http://www.protennislive.com/LSHD/main.html?year=" + year + "&wkno=" + wkno + "&eventid=" + eventid + "&tour=" + tour + "&lang=" + lang + "&ref=" + strCheckRef;
#
# 			var popupWin = window.open(lsURL, '_' + Math.round(Math.random() * 1000000), 'top=' + theTop + ',left=' + theLeft + ',menubar=0,toolbar=0,location=0,directories=0,status=0,' + scrollBars + ',width=' + theWidth + ', height=' + theHeight);
# 		}
# 		function openLSBTFWindow(year, wkno, eventid, tour, lang, ref_file, width, height, hasScrollBars) {
# 			// ADD NAME FIELD and make sure it get's focus!!!
# 			var theWidth = width;
# 			var theHeight = height;
# 			var scrollBars = "scrollbars";
# 			if (hasScrollBars == false) scrollBars = "scrollbars=0";
# 			if ((theWidth == "") || (theWidth == null)) theWidth = 1042;
# 			if ((theHeight == "") || (theHeight == null)) theHeight = 631;
# 			var theLeft = (screen.availWidth - theWidth) / 2;
# 			var theTop = (screen.availHeight - theHeight) / 2;
# 			var strCheckRef = escape(ref_file);
#
# 			lsURL = "http://www.protennislive.com/lsbtf/main.html?year=" + year + "&wkno=" + wkno + "&eventid=" + eventid + "&tour=" + tour + "&lang=" + lang + "&ref=" + strCheckRef;
#
# 			var popupWin = window.open(lsURL, '_' + Math.round(Math.random() * 1000000), 'top=' + theTop + ',left=' + theLeft + ',menubar=0,toolbar=0,location=0,directories=0,status=0,' + scrollBars + ',width=' + theWidth + ', height=' + theHeight);
# 		}
#
# Encountered an end tag : script
# Encountered some data  :
#
# Encountered a start tag: script
# Encountered some data  :
# 		setTimeout(function ()
# 		{ var a = document.createElement("script"); var b = document.getElementsByTagName("script")[0]; a.src = document.location.protocol + "//script.crazyegg.com/pages/scripts/0014/0351.js?" + Math.floor(new Date().getTime() / 3600000); a.async = true; a.type = "text/javascript"; b.parentNode.insertBefore(a, b) }
# 		, 1);
#
# Encountered an end tag : script
# Encountered some data  :
#
#
#
# Encountered an end tag : body
# Encountered some data  :
#
#
#
# Encountered some data  :
#
#
# Encountered an end tag : html
# Encountered some data  :
